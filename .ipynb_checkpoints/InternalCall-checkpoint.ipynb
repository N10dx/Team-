# %% [markdown]
# ### 1. Import the necessary libraries

# %%
# do not show warnings
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns
from datetime import datetime

# %% [markdown]
# ### 2. Data cleaning

# %% [markdown]
# This chapter contains the following:
# - Missing value handling
# - Inconsistent data handling
# - Rename columns and values and drop unnecessary columns
# - Duplicate data handling
# - Outlier handling

# %%
file = pd.read_csv('InternalCallL.csv')

# %%
df=pd.DataFrame(file)
df
# Out:
#       Unnamed: 0    Nr.  Unnamed: 1  Day                Date  Duration  \
# 0              0      1         NaN  Tue  3/14/2023 18:30:20  00:00:00
# 1              1      2         NaN  Tue  3/14/2023 18:30:20  00:00:00
# 2              2      3         NaN  Tue  3/14/2023 16:56:44  00:01:19
# 3              3      4         NaN  Tue  3/14/2023 16:56:44  00:01:19
# 4              4      5         NaN  Tue  3/14/2023 16:50:37  00:00:00
# ...          ...    ...         ...  ...                 ...       ...
# 9995        9995   9996         NaN  Sun  2/26/2023 11:21:02  00:00:00
# 9996        9996   9997         NaN  Sun  2/26/2023 11:20:51  00:00:31
# 9997        9997   9998         NaN  Sun  2/26/2023 11:20:51  00:00:31
# 9998        9998   9999         NaN  Sun  2/26/2023 11:17:47  00:01:10
# 9999        9999  10000         NaN  Sun  2/26/2023 11:17:47  00:01:10
#
#       Extension1 Ext.1 Name                        Ext.1 Dep.  Extension2  \
# 0            412        NaN                               NaN         755
# 1            755        NaN                               NaN         412
# 2            122   Mohammed          CyberSecurity Department         430
# 3            430   Mohammed            Information Technology         122
# 4            310     faiqah        Electro-Optics Systems Lab         105
# ...          ...        ...                               ...         ...
# 9995         118      Fahad    Documents and Archiving Center         400
# 9996         428   Sulaytin            Information Technology         415
# 9997         415    meshari            Information Technology         428
# 9998         407  abdulaziz  Facilities Management Department         408
# 9999         408     Musaad              Financial Accounting         407
#
#      Ext.2 Name                        Ext.2 Dep.  Type  Unnamed: 12   Status  \
# 0           NaN                               NaN  Inc.          NaN  Unansw.
# 1           NaN                               NaN   Out          NaN  Unansw.
# 2      Mohammed            Information Technology  Inc.          NaN    Answ.
# 3      Mohammed          CyberSecurity Department   Out          NaN    Answ.
# 4          syed          Strategic Planning / VRO  Inc.          NaN  Unansw.
# ...         ...                               ...   ...          ...      ...
# 9995    Ibrahim                    FSS Management   Out          NaN  Unansw.
# 9996    meshari            Information Technology  Inc.          NaN    Answ.
# 9997   Sulaytin            Information Technology   Out          NaN    Answ.
# 9998     Musaad              Financial Accounting  Inc.          NaN    Answ.
# 9999  abdulaziz  Facilities Management Department   Out          NaN    Answ.
#
#      Ring Time
# 0       0 sec.
# 1       0 sec.
# 2       5 sec.
# 3       5 sec.
# 4      20 sec.
# ...        ...
# 9995   30 sec.
# 9996    4 sec.
# 9997    4 sec.
# 9998   16 sec.
# 9999   16 sec.
#
# [10000 rows x 16 columns]

# %%
df.shape
# Out:
# (10000, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   10000 non-null  int64
#  1   Nr.          10000 non-null  int64
#  2   Unnamed: 1   0 non-null      float64
#  3   Day          10000 non-null  object
#  4   Date         10000 non-null  object
#  5   Duration     10000 non-null  object
#  6   Extension1   10000 non-null  int64
#  7   Ext.1 Name   9275 non-null   object
#  8   Ext.1 Dep.   9250 non-null   object
#  9   Extension2   10000 non-null  int64
#  10  Ext.2 Name   9275 non-null   object
#  11  Ext.2 Dep.   9250 non-null   object
#  12  Type         10000 non-null  object
#  13  Unnamed: 12  0 non-null      float64
#  14  Status       10000 non-null  object
#  15  Ring Time    10000 non-null  object
# dtypes: float64(2), int64(4), object(10)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#         Unnamed: 0          Nr.  Unnamed: 1   Extension1   Extension2  \
# count  10000.00000  10000.00000         0.0  10000.00000  10000.00000
# mean    4999.50000   5000.50000         NaN    349.12010    349.12010
# std     2886.89568   2886.89568         NaN    260.46436    260.46436
# min        0.00000      1.00000         NaN    102.00000    102.00000
# 25%     2499.75000   2500.75000         NaN    218.00000    218.00000
# 50%     4999.50000   5000.50000         NaN    411.00000    411.00000
# 75%     7499.25000   7500.25000         NaN    424.00000    424.00000
# max     9999.00000  10000.00000         NaN   7600.00000   7600.00000
#
#        Unnamed: 12
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %% [markdown]
# #### 1. Rename columns and values and drop unnecessary columns

# %%
df.rename(columns = {"Ext.1 Name":"Extension1_Name","Ext.2 Name":"Extension2_Name",
                     "Ext.1 Dep.":"Extension1_Department","Ext.2 Dep.":"Extension2_Department",
                     "Ring Time":"Ring_time_per_second"},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             10000 non-null  int64
#  1   Nr.                    10000 non-null  int64
#  2   Unnamed: 1             0 non-null      float64
#  3   Day                    10000 non-null  object
#  4   Date                   10000 non-null  object
#  5   Duration               10000 non-null  object
#  6   Extension1             10000 non-null  int64
#  7   Extension1_Name        9275 non-null   object
#  8   Extension1_Department  9250 non-null   object
#  9   Extension2             10000 non-null  int64
#  10  Extension2_Name        9275 non-null   object
#  11  Extension2_Department  9250 non-null   object
#  12  Type                   10000 non-null  object
#  13  Unnamed: 12            0 non-null      float64
#  14  Status                 10000 non-null  object
#  15  Ring_time_per_second   10000 non-null  object
# dtypes: float64(2), int64(4), object(10)
# memory usage: 1.2+ MB

# %%
df["Type"]=df["Type"].map({"Inc." : "Income" , "Out" : "Outcome"})
df["Type"].value_counts()
# Out:
# Income     5000
# Outcome    5000
# Name: Type, dtype: int64

# %%
df["Status"]=df["Status"].map({"Answ." : "Answer" , "Unansw." : "Unnswer"})
df["Status"].value_counts()
# Out:
# Answer     5456
# Unnswer    4544
# Name: Status, dtype: int64

# %%
df["Extension1_Name"].value_counts()
# Out:
# Abdulelah      673
# Abdullah       399
# mohammed       344
# muhrah         324
# meshal         314
#               ...
# Sara             2
# Saleh            1
# suliman          1
# Muntasir         1
# Abdulfattah      1
# Name: Extension1_Name, Length: 104, dtype: int64

# %%
df["Extension2_Name"].value_counts()
# Out:
# Abdulelah      673
# Abdullah       399
# mohammed       344
# muhrah         324
# meshal         314
#               ...
# Sara             2
# Saleh            1
# suliman          1
# Muntasir         1
# Abdulfattah      1
# Name: Extension2_Name, Length: 104, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             10000 non-null  int64
#  1   Nr.                    10000 non-null  int64
#  2   Unnamed: 1             0 non-null      float64
#  3   Day                    10000 non-null  object
#  4   Date                   10000 non-null  object
#  5   Duration               10000 non-null  object
#  6   Extension1             10000 non-null  int64
#  7   Extension1_Name        9275 non-null   object
#  8   Extension1_Department  9250 non-null   object
#  9   Extension2             10000 non-null  int64
#  10  Extension2_Name        9275 non-null   object
#  11  Extension2_Department  9250 non-null   object
#  12  Type                   10000 non-null  object
#  13  Unnamed: 12            0 non-null      float64
#  14  Status                 10000 non-null  object
#  15  Ring_time_per_second   10000 non-null  object
# dtypes: float64(2), int64(4), object(10)
# memory usage: 1.2+ MB

# %% [markdown]
# #### 2. Missing value handling

# %%
# check for null values 
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# Nr.                          0
# Unnamed: 1               10000
# Day                          0
# Date                         0
# Duration                     0
# Extension1                   0
# Extension1_Name            725
# Extension1_Department      750
# Extension2                   0
# Extension2_Name            725
# Extension2_Department      750
# Type                         0
# Unnamed: 12              10000
# Status                       0
# Ring_time_per_second         0
# dtype: int64

# %%
df[df['Extension1_Department'].isnull()].head(5)# the nulls for test or before assign an user
# Out:
#      Unnamed: 0  Nr.  Unnamed: 1  Day                Date  Duration  \
# 0             0    1         NaN  Tue  3/14/2023 18:30:20  00:00:00
# 1             1    2         NaN  Tue  3/14/2023 18:30:20  00:00:00
# 80           80   81         NaN  Tue  3/14/2023 15:28:33  00:00:24
# 118         118  119         NaN  Tue  3/14/2023 15:02:36  00:00:00
# 130         130  131         NaN  Tue  3/14/2023 14:57:08  00:00:12
#
#      Extension1 Extension1_Name Extension1_Department  Extension2  \
# 0           412             NaN                   NaN         755
# 1           755             NaN                   NaN         412
# 80          412             NaN                   NaN         400
# 118         850             NaN                   NaN         111
# 130         412             NaN                   NaN         112
#
#     Extension2_Name       Extension2_Department     Type  Unnamed: 12  \
# 0               NaN                         NaN   Income          NaN
# 1               NaN                         NaN  Outcome          NaN
# 80          Ibrahim              FSS Management   Income          NaN
# 118       Abdulelah  General Directorate Office   Income          NaN
# 130             NaN                         NaN   Income          NaN
#
#       Status Ring_time_per_second
# 0    Unnswer               0 sec.
# 1    Unnswer               0 sec.
# 80    Answer               5 sec.
# 118  Unnswer               6 sec.
# 130   Answer               7 sec.

# %%
# Drop missing values,which is for testing
df=df.dropna(axis=0,subset=['Extension2_Name','Extension1_Name','Extension1_Department','Extension2_Department'],how='any')
df
# Out:
#       Unnamed: 0    Nr.  Unnamed: 1  Day                Date  Duration  \
# 2              2      3         NaN  Tue  3/14/2023 16:56:44  00:01:19
# 3              3      4         NaN  Tue  3/14/2023 16:56:44  00:01:19
# 4              4      5         NaN  Tue  3/14/2023 16:50:37  00:00:00
# 5              5      6         NaN  Tue  3/14/2023 16:50:37  00:00:00
# 6              6      7         NaN  Tue  3/14/2023 16:35:52  00:00:00
# ...          ...    ...         ...  ...                 ...       ...
# 9995        9995   9996         NaN  Sun  2/26/2023 11:21:02  00:00:00
# 9996        9996   9997         NaN  Sun  2/26/2023 11:20:51  00:00:31
# 9997        9997   9998         NaN  Sun  2/26/2023 11:20:51  00:00:31
# 9998        9998   9999         NaN  Sun  2/26/2023 11:17:47  00:01:10
# 9999        9999  10000         NaN  Sun  2/26/2023 11:17:47  00:01:10
#
#       Extension1 Extension1_Name  \
# 2            122        Mohammed
# 3            430        Mohammed
# 4            310          faiqah
# 5            105            syed
# 6            219        mohammed
# ...          ...             ...
# 9995         118           Fahad
# 9996         428        Sulaytin
# 9997         415         meshari
# 9998         407       abdulaziz
# 9999         408          Musaad
#
#                                   Extension1_Department  Extension2  \
# 2                              CyberSecurity Department         430
# 3                                Information Technology         122
# 4                            Electro-Optics Systems Lab         105
# 5                              Strategic Planning / VRO         310
# 6     Legal Affairs, Partnerships & International Co...         501
# ...                                                 ...         ...
# 9995                     Documents and Archiving Center         400
# 9996                             Information Technology         415
# 9997                             Information Technology         428
# 9998                   Facilities Management Department         408
# 9999                               Financial Accounting         407
#
#      Extension2_Name                             Extension2_Department  \
# 2           Mohammed                            Information Technology
# 3           Mohammed                          CyberSecurity Department
# 4               syed                          Strategic Planning / VRO
# 5             faiqah                        Electro-Optics Systems Lab
# 6           mohammed  Business Development and Corporate Communication
# ...              ...                                               ...
# 9995         Ibrahim                                    FSS Management
# 9996         meshari                            Information Technology
# 9997        Sulaytin                            Information Technology
# 9998          Musaad                              Financial Accounting
# 9999       abdulaziz                  Facilities Management Department
#
#          Type  Unnamed: 12   Status Ring_time_per_second
# 2      Income          NaN   Answer               5 sec.
# 3     Outcome          NaN   Answer               5 sec.
# 4      Income          NaN  Unnswer              20 sec.
# 5     Outcome          NaN  Unnswer              20 sec.
# 6      Income          NaN  Unnswer              43 sec.
# ...       ...          ...      ...                  ...
# 9995  Outcome          NaN  Unnswer              30 sec.
# 9996   Income          NaN   Answer               4 sec.
# 9997  Outcome          NaN   Answer               4 sec.
# 9998   Income          NaN   Answer              16 sec.
# 9999  Outcome          NaN   Answer              16 sec.
#
# [8734 rows x 16 columns]

# %%
#drop unusefull columns
df = df.drop(['Extension1' ,'Extension2','Unnamed: 1','Unnamed: 12','Unnamed: 0','Nr.'], axis=1)
df.head()
# Out:
#    Day                Date  Duration Extension1_Name  \
# 2  Tue  3/14/2023 16:56:44  00:01:19        Mohammed
# 3  Tue  3/14/2023 16:56:44  00:01:19        Mohammed
# 4  Tue  3/14/2023 16:50:37  00:00:00          faiqah
# 5  Tue  3/14/2023 16:50:37  00:00:00            syed
# 6  Tue  3/14/2023 16:35:52  00:00:00        mohammed
#
#                                Extension1_Department Extension2_Name  \
# 2                           CyberSecurity Department        Mohammed
# 3                             Information Technology        Mohammed
# 4                         Electro-Optics Systems Lab            syed
# 5                           Strategic Planning / VRO          faiqah
# 6  Legal Affairs, Partnerships & International Co...        mohammed
#
#                               Extension2_Department     Type   Status  \
# 2                            Information Technology   Income   Answer
# 3                          CyberSecurity Department  Outcome   Answer
# 4                          Strategic Planning / VRO   Income  Unnswer
# 5                        Electro-Optics Systems Lab  Outcome  Unnswer
# 6  Business Development and Corporate Communication   Income  Unnswer
#
#   Ring_time_per_second
# 2               5 sec.
# 3               5 sec.
# 4              20 sec.
# 5              20 sec.
# 6              43 sec.

# %%
df.isnull().sum()
# Out:
# Day                      0
# Date                     0
# Duration                 0
# Extension1_Name          0
# Extension1_Department    0
# Extension2_Name          0
# Extension2_Department    0
# Type                     0
# Status                   0
# Ring_time_per_second     0
# dtype: int64

# %% [markdown]
# #### 3. Inconsistent data handling

# %%
df['Date'] = pd.to_datetime(df['Date'],errors='coerce')

# %%
df["Date"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 8734 entries, 2 to 9999
# Series name: Date
# Non-Null Count  Dtype
# --------------  -----
# 8734 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 136.5 KB

# %%
df.head(1)
# Out:
#    Day                Date  Duration Extension1_Name  \
# 2  Tue 2023-03-14 16:56:44  00:01:19        Mohammed
#
#       Extension1_Department Extension2_Name   Extension2_Department    Type  \
# 2  CyberSecurity Department        Mohammed  Information Technology  Income
#
#    Status Ring_time_per_second
# 2  Answer               5 sec.

# %%
df['Duration'] = pd.to_timedelta(df['Duration'])

# %%
df.head(5)
# Out:
#    Day                Date        Duration Extension1_Name  \
# 2  Tue 2023-03-14 16:56:44 0 days 00:01:19        Mohammed
# 3  Tue 2023-03-14 16:56:44 0 days 00:01:19        Mohammed
# 4  Tue 2023-03-14 16:50:37 0 days 00:00:00          faiqah
# 5  Tue 2023-03-14 16:50:37 0 days 00:00:00            syed
# 6  Tue 2023-03-14 16:35:52 0 days 00:00:00        mohammed
#
#                                Extension1_Department Extension2_Name  \
# 2                           CyberSecurity Department        Mohammed
# 3                             Information Technology        Mohammed
# 4                         Electro-Optics Systems Lab            syed
# 5                           Strategic Planning / VRO          faiqah
# 6  Legal Affairs, Partnerships & International Co...        mohammed
#
#                               Extension2_Department     Type   Status  \
# 2                            Information Technology   Income   Answer
# 3                          CyberSecurity Department  Outcome   Answer
# 4                          Strategic Planning / VRO   Income  Unnswer
# 5                        Electro-Optics Systems Lab  Outcome  Unnswer
# 6  Business Development and Corporate Communication   Income  Unnswer
#
#   Ring_time_per_second
# 2               5 sec.
# 3               5 sec.
# 4              20 sec.
# 5              20 sec.
# 6              43 sec.

# %%
df["Duration"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 8734 entries, 2 to 9999
# Series name: Duration
# Non-Null Count  Dtype
# --------------  -----
# 8734 non-null   timedelta64[ns]
# dtypes: timedelta64[ns](1)
# memory usage: 136.5 KB

# %%
df['Ring_time_per_second'] = df['Ring_time_per_second'].str.replace("sec.", "")

# %%
df['Ring_time_per_second'].value_counts()
# Out:
# 3       1020
# 4        920
# 5        554
# 6        514
# 2        400
#         ...
# 628        2
# 76         2
# 621        2
# 790        2
# 647        2
# Name: Ring_time_per_second, Length: 170, dtype: int64

# %%
df['Ring_time_per_second'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 8734 entries, 2 to 9999
# Series name: Ring_time_per_second
# Non-Null Count  Dtype
# --------------  -----
# 8734 non-null   object
# dtypes: object(1)
# memory usage: 136.5+ KB

# %%
df['Ring_time_per_second'] = pd.to_numeric(df['Ring_time_per_second'])

# %%
df['Ring_time_per_second'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 8734 entries, 2 to 9999
# Series name: Ring_time_per_second
# Non-Null Count  Dtype
# --------------  -----
# 8734 non-null   int64
# dtypes: int64(1)
# memory usage: 136.5 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8734 entries, 2 to 9999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Day                    8734 non-null   object
#  1   Date                   8734 non-null   datetime64[ns]
#  2   Duration               8734 non-null   timedelta64[ns]
#  3   Extension1_Name        8734 non-null   object
#  4   Extension1_Department  8734 non-null   object
#  5   Extension2_Name        8734 non-null   object
#  6   Extension2_Department  8734 non-null   object
#  7   Type                   8734 non-null   object
#  8   Status                 8734 non-null   object
#  9   Ring_time_per_second   8734 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(7), timedelta64[ns](1)
# memory usage: 750.6+ KB

# %% [markdown]
# #### 3. Outlier handling

# %%
#show the outlier
df.plot(kind ='box', subplots=True,figsize=(10,5));

# %%
Q1 = df.Ring_time_per_second.quantile(0.25)
Q3 = df.Ring_time_per_second.quantile(0.75)
IQR = Q3-Q1
upper = Q3 + 1.5*IQR
df.loc[df["Ring_time_per_second"] > upper,"Ring_time_per_second"] = upper

# %%
sns.boxplot(x = df["Ring_time_per_second"]);

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8734 entries, 2 to 9999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Day                    8734 non-null   object
#  1   Date                   8734 non-null   datetime64[ns]
#  2   Duration               8734 non-null   timedelta64[ns]
#  3   Extension1_Name        8734 non-null   object
#  4   Extension1_Department  8734 non-null   object
#  5   Extension2_Name        8734 non-null   object
#  6   Extension2_Department  8734 non-null   object
#  7   Type                   8734 non-null   object
#  8   Status                 8734 non-null   object
#  9   Ring_time_per_second   8734 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(7), timedelta64[ns](1)
# memory usage: 750.6+ KB

# %% [markdown]
# #### 5. Duplicate data handling

# %%
# Check for duplicate value
sum(df.duplicated())
# Out:
# 0

# %%
df.shape
# Out:
# (8734, 10)

# %%
df.describe()
# Out:
#                         Duration  Ring_time_per_second
# count                       8734           8734.000000
# mean   0 days 00:00:51.641630409             14.576826
# std    0 days 00:02:05.793676487             13.612019
# min              0 days 00:00:00              0.000000
# 25%              0 days 00:00:00              4.000000
# 50%              0 days 00:00:10              9.000000
# 75%              0 days 00:00:54             21.000000
# max              0 days 00:52:46             46.500000

# %% [markdown]
# #### 6.To make data readable

# %%
df['Name and Department ex1']= df['Extension1_Name']+': '+df['Extension1_Department']
df['Name and Department ex2']= df['Extension2_Name']+': '+df['Extension2_Department']
df.head()
# Out:
#    Day                Date        Duration Extension1_Name  \
# 2  Tue 2023-03-14 16:56:44 0 days 00:01:19        Mohammed
# 3  Tue 2023-03-14 16:56:44 0 days 00:01:19        Mohammed
# 4  Tue 2023-03-14 16:50:37 0 days 00:00:00          faiqah
# 5  Tue 2023-03-14 16:50:37 0 days 00:00:00            syed
# 6  Tue 2023-03-14 16:35:52 0 days 00:00:00        mohammed
#
#                                Extension1_Department Extension2_Name  \
# 2                           CyberSecurity Department        Mohammed
# 3                             Information Technology        Mohammed
# 4                         Electro-Optics Systems Lab            syed
# 5                           Strategic Planning / VRO          faiqah
# 6  Legal Affairs, Partnerships & International Co...        mohammed
#
#                               Extension2_Department     Type   Status  \
# 2                            Information Technology   Income   Answer
# 3                          CyberSecurity Department  Outcome   Answer
# 4                          Strategic Planning / VRO   Income  Unnswer
# 5                        Electro-Optics Systems Lab  Outcome  Unnswer
# 6  Business Development and Corporate Communication   Income  Unnswer
#
#    Ring_time_per_second                            Name and Department ex1  \
# 2                   5.0                 Mohammed: CyberSecurity Department
# 3                   5.0                   Mohammed: Information Technology
# 4                  20.0                 faiqah: Electro-Optics Systems Lab
# 5                  20.0                     syed: Strategic Planning / VRO
# 6                  43.0  mohammed: Legal Affairs, Partnerships & Intern...
#
#                              Name and Department ex2
# 2                   Mohammed: Information Technology
# 3                 Mohammed: CyberSecurity Department
# 4                     syed: Strategic Planning / VRO
# 5                 faiqah: Electro-Optics Systems Lab
# 6  mohammed: Business Development and Corporate C...
